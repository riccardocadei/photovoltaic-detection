# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot  as plt
import cv2
from loss import *
# %load_ext autoreload
# %autoreload 2

# %%
image1 = cv2.imread("1.png")[:,:,0] # takes only a single color channel, and puts 1 and 0 labels
image1[image1 > 0] = 1 # and puts 1 and 0 labels
image2 = cv2.imread("2.png")[:,:,0] # takes only a single color channel,
image2[image2 > 0] = 1 # and puts 1 and 0 labels

# turns them into tensor
x1 = torch.tensor(image1)
x2 = torch.tensor(image2)

# %%
plt.imshow(image1)
plt.show()
plt.imshow(image2)

# %%
iou(x1.numpy(),x2.numpy())
# Out:
# 0.14418724945040734

# %%
accuracy(x1.numpy(),x2.numpy())
# Out:
# 0.788224

# %%
recall(x1.numpy(),x2.numpy())
# Out:
# 0.2520343580470163
