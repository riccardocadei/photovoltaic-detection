# %%
from os import listdir
from os.path import isfile, join

# %%
path = 'data/image'
copy = 'data/mask'

# %%
onlyfiles = ['data/mask_residencial/'+f[:-4]+'_label.png' for f in listdir(path) if isfile(join(path, f))]
copyfiles = [f for f in listdir(copy) if isfile(join(copy,f))]

# %%
for file in copyfiles:
    if !(file in onlyfiles):
        os.remove(file)
# Out:
# _LV03_1301_11_2015_1_15_497937.5_121625.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_119187.5_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_119625.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_119687.5_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_119875.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_119937.5_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120000.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120062.5_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120125.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120250.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120375.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120437.5_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120500.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120750.0_label.png',
#  'DOP25_LV03_1301_11_2015_1_15_498000.0_120875.0_label.png',
# ...
